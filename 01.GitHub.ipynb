# %%
### Script to get GitHub profile data of all Stargazers of a given GitHub repository 
###
###    by Max Woolf (@minimaxir)

import json
import csv
import urllib.request as urllib2
import urllib.request
import datetime
import time
import GHKeys as mystuff
import os.path
import pickle

# %%
def getInfo(user,repository):

    repo = user+"/"+repository

    fields = ["user_id", "username", "num_followers", "num_following", "num_repos","created_at","star_time"]
    page_number = 0
    users_processed = 0
    stars_remaining = True
    list_stars = []

    print("Gathering Stargazers for %s..." % repo)

    ###
    ###    This block of code creates a list of tuples in the form of (username, star_time)
    ###    for the Statgazers, which will laterbe used to extract full GitHub profile data
    ###

    while stars_remaining:
        query_url = "https://api.github.com/repos/%s/stargazers?page=%s&access_token=%s" % (repo, page_number, mystuff.access_token)

        req = urllib.request.Request(query_url)
        req.add_header('Accept', 'application/vnd.github.v3.star+json')
        try:
            response = urllib.request.urlopen(req)
        except:
            pass
        data = json.loads(response.read())

        for user in data:
            username = user['user']['login']

            star_time = datetime.datetime.strptime(user['starred_at'],'%Y-%m-%dT%H:%M:%SZ')
            star_time = star_time + datetime.timedelta(hours=-5) # EST
            star_time = star_time.strftime('%Y-%m-%d %H:%M:%S')

            list_stars.append((username, star_time))

        if len(data) < 25:
            stars_remaining = False

        page_number += 1

    print("Done Gathering Stargazers for %s!" % repo)

    list_stars = list(set(list_stars)) # remove dupes

    print("Now Gathering Stargazers' GitHub Profiles...")

    ###
    ###    This block of code extracts the full profile data of the given Stargazer
    ###    and writes to CSV
    ###

    with open('%s-stargazers.csv' % repo.split('/')[1], 'w') as stars:
        print(fields)
        stars_writer = csv.writer(stars)
        stars_writer.writerow(fields)

        for user in list_stars:
            username = user[0]

            query_url = "https://api.github.com/users/%s?access_token=%s" % (username, mystuff.access_token)

            req = urllib.request.Request(query_url)
            try:
                response = urllib.request.urlopen(req)
            except:
                pass
            data = json.loads(response.read())

            user_id = data['id']
            num_followers = data['followers']
            num_following = data['following']
            num_repos = data['public_repos']

            created_at = datetime.datetime.strptime(data['created_at'],'%Y-%m-%dT%H:%M:%SZ')
            created_at = created_at + datetime.timedelta(hours=-5) # EST
            created_at = created_at.strftime('%Y-%m-%d %H:%M:%S')

            stars_writer.writerow([user_id, username, num_followers, num_following, num_repos, created_at, user[1]])

            users_processed += 1

            if users_processed % 100 == 0:
                print("%s Users Processed: %s" % (users_processed, datetime.datetime.now()))

            time.sleep(1) # stay within API rate limit of 5000 requests / hour + buffer

# %%
getInfo("kelu124","vit3rick")
getInfo("kelu124","lit3rick")
getInfo("kelu124","pyUn0-lib")
getInfo("kelu124","un0rick")
getInfo("kelu124","echomods")
# Out:
# Gathering Stargazers for kelu124/vit3rick...
# Done Gathering Stargazers for kelu124/vit3rick!
# Now Gathering Stargazers' GitHub Profiles...
# ['user_id', 'username', 'num_followers', 'num_following', 'num_repos', 'created_at', 'star_time']
# Gathering Stargazers for kelu124/lit3rick...
# Done Gathering Stargazers for kelu124/lit3rick!
# Now Gathering Stargazers' GitHub Profiles...
# ['user_id', 'username', 'num_followers', 'num_following', 'num_repos', 'created_at', 'star_time']
# Gathering Stargazers for kelu124/pyUn0-lib...
# Done Gathering Stargazers for kelu124/pyUn0-lib!
# Now Gathering Stargazers' GitHub Profiles...
# ['user_id', 'username', 'num_followers', 'num_following', 'num_repos', 'created_at', 'star_time']

# %%
def getWatcher(USERNAME,repository):

    repo = USERNAME+"/"+repository

    fields = ["user_id", "username", "num_followers", "num_following", "num_repos","created_at","star_time"]
    page_number = 0
    users_processed = 0
    stars_remaining = True
    list_stars = []

    print("Gathering subscribers for %s..." % repo)

    ###
    ###    This block of code creates a list of tuples in the form of (username, star_time)
    ###    for the Statgazers, which will laterbe used to extract full GitHub profile data
    ###

    while stars_remaining:
        query_url = "https://api.github.com/repos/%s/subscribers?page=%s&access_token=%s" % (repo, page_number, mystuff.access_token)

        req = urllib.request.Request(query_url)
        req.add_header('Accept', 'application/vnd.github.v3.star+json')
        try:
            response = urllib.request.urlopen(req)
        except:
            pass
        data = json.loads(response.read())
        #print(data)
        for user in data:
            username = user['login']

            list_stars.append(username)

        if len(data) < 25:
            stars_remaining = False

        page_number += 1

    print("Done Gathering subscribers for %s!" % repo)
    with open("./project_pkl/"+USERNAME+"_"+repository+'_suscribers.pkl', 'wb') as f:
        pickle.dump(list_stars, f)
    return list_stars

# %%
getWatcher("kelu124","vit3rick")
getWatcher("kelu124","lit3rick")
getWatcher("kelu124","pyUn0-lib")
getWatcher("kelu124","un0rick")
getWatcher("kelu124","echomods")
# Out:
# Gathering subscribers for kelu124/vit3rick...
# Done Gathering subscribers for kelu124/vit3rick!
# Gathering subscribers for kelu124/lit3rick...
# Done Gathering subscribers for kelu124/lit3rick!
# Gathering subscribers for kelu124/pyUn0-lib...
# Done Gathering subscribers for kelu124/pyUn0-lib!
# Gathering subscribers for kelu124/un0rick...
# Done Gathering subscribers for kelu124/un0rick!
# Gathering subscribers for kelu124/echomods...
# Done Gathering subscribers for kelu124/echomods!
# ['kelu124',
#  'DINKIN',
#  'openube',
#  'bobnet',
#  'fabiogiordani',
#  'blakme',
#  'antouanbg',
#  'boyihao-utp',
#  'wlmeng11',
#  'docfabio',
#  'thecomicopera',
#  'ChunHsinTung',
#  'Doom4535',
#  'dmitry-sukhoruchkin',
#  'aperocks',
#  '10syle',
#  'g4idrijs',
#  'AnttiLukats',
#  'yuntianrenren',
#  'JeanRintoul',
#  'diegslva',
#  'basharbme',
#  'mxochicale',
#  'Felipeasg',
#  'prasimix',
#  'ykeraichia',
#  'Bobbyjoness',
#  'hetykai',
#  'justicelee',
#  'cmadh',
#  'kelu124',
#  'DINKIN',
#  'openube',
#  'bobnet',
#  'fabiogiordani',
#  'blakme',
#  'antouanbg',
#  'boyihao-utp',
#  'wlmeng11',
#  'docfabio',
#  'thecomicopera',
#  'ChunHsinTung',
#  'Doom4535',
#  'dmitry-sukhoruchkin',
#  'aperocks',
#  '10syle',
#  'g4idrijs',
#  'AnttiLukats',
#  'yuntianrenren',
#  'JeanRintoul',
#  'diegslva',
#  'basharbme',
#  'mxochicale',
#  'Felipeasg',
#  'prasimix',
#  'ykeraichia',
#  'Bobbyjoness',
#  'hetykai',
#  'justicelee',
#  'cmadh',
#  'panzerkiller',
#  'serhargun']

# %%
def getForks(USERNAME,repository):

    repo = USERNAME+"/"+repository

    fields = ["user_id", "username", "num_followers", "num_following", "num_repos","created_at","star_time"]
    page_number = 0
    users_processed = 0
    stars_remaining = True
    list_stars = []

    print("Gathering subscribers for %s..." % repo)

    ###
    ###    This block of code creates a list of tuples in the form of (username, star_time)
    ###    for the Statgazers, which will laterbe used to extract full GitHub profile data
    ###

    while stars_remaining:
        query_url = "https://api.github.com/repos/%s/forks?page=%s&access_token=%s" % (repo, page_number, mystuff.access_token)

        req = urllib.request.Request(query_url)
        req.add_header('Accept', 'application/vnd.github.v3.star+json')
        try:
            response = urllib.request.urlopen(req)
        except:
            pass
        data = json.loads(response.read())
        #print(data)
        for user in data:
            username = user['owner']['login']

            list_stars.append(username)

        if len(data) < 25:
            stars_remaining = False

        page_number += 1

    print("Done Gathering subscribers for %s!" % repo)
    with open("./project_pkl/"+USERNAME+"_"+repository+'_forks.pkl', 'wb') as f:
        pickle.dump(list_stars, f)
    return list_stars

# %%
getForks("kelu124","vit3rick")
getForks("kelu124","lit3rick")
getForks("kelu124","pyUn0-lib")
getForks("kelu124","un0rick")
getForks("kelu124","echomods")
# Out:
# Gathering subscribers for kelu124/vit3rick...
# Done Gathering subscribers for kelu124/vit3rick!
# Gathering subscribers for kelu124/lit3rick...
# Done Gathering subscribers for kelu124/lit3rick!
# Gathering subscribers for kelu124/pyUn0-lib...
# Done Gathering subscribers for kelu124/pyUn0-lib!
# Gathering subscribers for kelu124/un0rick...
# Done Gathering subscribers for kelu124/un0rick!
# Gathering subscribers for kelu124/echomods...
# Done Gathering subscribers for kelu124/echomods!
# ['sysclock',
#  'mtubpeng1',
#  'kevinn1999',
#  'mohammadfatemieh',
#  'panzerkiller',
#  'oring111',
#  'Yarulik',
#  'Hendryputra',
#  'fabriciopk',
#  'r4forth',
#  'trungnpt',
#  'riscmcu',
#  'fcqing',
#  'DuoBelt',
#  'dev1104',
#  'jammie',
#  'ascillato',
#  'octavianCraciun',
#  'YaweiZhao',
#  'djson',
#  'awantae',
#  'basharbme',
#  'sunjiangbo',
#  'h798471649',
#  'zhangsinap',
#  'Graal76',
#  'TobiG77',
#  'amashal',
#  'ZebraTech',
#  'vck',
#  'sysclock',
#  'mtubpeng1',
#  'kevinn1999',
#  'mohammadfatemieh',
#  'panzerkiller',
#  'oring111',
#  'Yarulik',
#  'Hendryputra',
#  'fabriciopk',
#  'r4forth',
#  'trungnpt',
#  'riscmcu',
#  'fcqing',
#  'DuoBelt',
#  'dev1104',
#  'jammie',
#  'ascillato',
#  'octavianCraciun',
#  'YaweiZhao',
#  'djson',
#  'awantae',
#  'basharbme',
#  'sunjiangbo',
#  'h798471649',
#  'zhangsinap',
#  'Graal76',
#  'TobiG77',
#  'amashal',
#  'ZebraTech',
#  'vck',
#  'dzwpusa',
#  'maswangy',
#  'trigrass2',
#  'jtwiefel',
#  '416104443',
#  'docfabio',
#  'AdLibitumTechnologies',
#  'QuantumZhang',
#  'zhouzhuhuang',
#  'dezdeepblue',
#  'huleg',
#  'soobash',
#  'mahiraltay',
#  'LiShuai1225',
#  'Guokr1991',
#  'openube',
#  'g4idrijs',
#  'ZTaylor39',
#  'DINKIN']

# %%
def getStars(USERNAME,repository):

    repo = USERNAME+"/"+repository

    fields = ["user_id", "username", "num_followers", "num_following", "num_repos","created_at","star_time"]
    page_number = 0
    users_processed = 0
    stars_remaining = True
    list_stars = []

    print("Gathering Stargazers for %s..." % repo)

    ###
    ###    This block of code creates a list of tuples in the form of (username, star_time)
    ###    for the Statgazers, which will laterbe used to extract full GitHub profile data
    ###

    while stars_remaining:
        query_url = "https://api.github.com/repos/%s/stargazers?page=%s&access_token=%s" % (repo, page_number, mystuff.access_token)

        req = urllib.request.Request(query_url)
        req.add_header('Accept', 'application/vnd.github.v3.star+json')
        try:
            response = urllib.request.urlopen(req)
        except:
            pass
        data = json.loads(response.read())

        for user in data:
            username = user['user']['login']


            list_stars.append(username)

        if len(data) < 25:
            stars_remaining = False

        page_number += 1

    print("Done Gathering Stargazers for %s!" % repo)

    list_stars = list(set(list_stars)) # remove dupes
    print("Done Gathering subscribers for %s!" % repo)
    with open("./project_pkl/"+USERNAME+"_"+repository+'_stars.pkl', 'wb') as f:
        pickle.dump(list_stars, f)
    return list_stars

# %%
getStars("kelu124","vit3rick")
getStars("kelu124","lit3rick")
getStars("kelu124","pyUn0-lib")
getStars("kelu124","un0rick")
getStars("kelu124","echomods")
# Out:
# Gathering Stargazers for kelu124/vit3rick...
# Done Gathering Stargazers for kelu124/vit3rick!
# Done Gathering subscribers for kelu124/vit3rick!
# Gathering Stargazers for kelu124/lit3rick...
# Done Gathering Stargazers for kelu124/lit3rick!
# Done Gathering subscribers for kelu124/lit3rick!
# Gathering Stargazers for kelu124/pyUn0-lib...
# Done Gathering Stargazers for kelu124/pyUn0-lib!
# Done Gathering subscribers for kelu124/pyUn0-lib!
# Gathering Stargazers for kelu124/un0rick...
# Done Gathering Stargazers for kelu124/un0rick!
# Done Gathering subscribers for kelu124/un0rick!
# Gathering Stargazers for kelu124/echomods...
# Done Gathering Stargazers for kelu124/echomods!
# Done Gathering subscribers for kelu124/echomods!
# ['rrozestw',
#  'goeblr',
#  'rapha-opensource',
#  'r06548032',
#  'harlanw',
#  'hwwong',
#  'panamantis',
#  'thewtex',
#  'boyihao-utp',
#  'bhattisatish',
#  'zentown',
#  'mlp6',
#  'kelu124',
#  'DircoDT',
#  'davidonet',
#  'diegslva',
#  'tangym',
#  'alsrgv',
#  'matlab379',
#  'DINKIN',
#  'rene-aguirre',
#  'yyyg45',
#  'kovachwt',
#  'uid89626',
#  'jaanpehechaanho',
#  'selftaught',
#  'Felipeasg',
#  'wly0215',
#  'suyashkumar',
#  'mediovia',
#  'bensooter',
#  'robksawyer',
#  'anfractuosity',
#  'mxochicale',
#  'XinShuYang',
#  'ARezaK',
#  'qinshiysb',
#  'julescarbon',
#  'cleder',
#  'orakle',
#  'elmsfu',
#  'shakhmetov',
#  'openube',
#  'paul-monokoto',
#  'Guokr1991',
#  'baibaratsky',
#  'robotong',
#  'Ritaqk',
#  'Jingfeng-LU',
#  'Bobbyjoness',
#  'clf1985',
#  'DuoBelt',
#  'milkowski',
#  'DigiMaxIO',
#  'IanBoyanZhang',
#  'Doom4535',
#  'lancemk',
#  'Palantir555',
#  'wlmeng11',
#  '07bm27',
#  'annafieber',
#  'JoyDoSun',
#  'cooldenng',
#  'pkral78',
#  'josecohenca',
#  'klonggan',
#  'DannyRavi',
#  'eobodo',
#  'Alberts00',
#  'guillaumedavidphd',
#  'lograss',
#  'speters',
#  'loredanacirstea',
#  'HINATASDK',
#  'joer14',
#  'levthedev',
#  'antoniocarreiro',
#  'sponnusa',
#  'ats777',
#  'ChunHsinTung',
#  'MartinBloedorn',
#  'TobiG77',
#  'justicelee',
#  'aaronfowles',
#  'gelonsun',
#  'masoud-al',
#  'mitoksim',
#  'ykeraichia',
#  'E3V3A',
#  'TroySK',
#  'docfabio',
#  'reportingsjr',
#  'eastleader1982',
#  'gaurav000144',
#  'taopanpan',
#  'DrKenHo',
#  'ZebraTech',
#  'chechu2k5',
#  'akc5233206',
#  'kubawolanin',
#  'JustGitting',
#  'PanPan0210',
#  'DFNOsorio',
#  '416104443',
#  'denisfitz57',
#  'mckaydavis',
#  'AbhishekGhosh',
#  'ovcharenkoo',
#  'mslavescu',
#  'DjalelBBZ',
#  'basharbme',
#  'mohamed',
#  'imgray',
#  'prasimix',
#  'urill',
#  'manis404',
#  'dalmago',
#  'GitMoDu',
#  'nyok',
#  'dmitry-sukhoruchkin',
#  '0xdevalias',
#  'yanpozka',
#  'olihb',
#  'ebgaaron',
#  'betolink',
#  'jarmitage',
#  'masip85',
#  'cHemingway',
#  'panzerkiller',
#  'huleg',
#  'yangjion',
#  'kamilchm',
#  'iseanstevens',
#  'rexpan',
#  'electronics4fun',
#  'nrepian',
#  'danilogr',
#  'goran-mahovlic',
#  'JeanRintoul',
#  'thecomicopera',
#  'junhua-zhang',
#  'DragonStuff',
#  'smcgill3',
#  'JohnGitHub886',
#  'longda',
#  'dezdeepblue',
#  'langthom',
#  'artursg',
#  'dzeez',
#  'tomfleet']

# %%
import glob, os
AllUsers = []
for file in glob.glob("./project_pkl/*.pkl"):
    #print(file)
    with open(file, 'rb') as f:
        listusers = pickle.load(f)
    for OneUser in listusers:
        AllUsers.append(OneUser)
        
AllUsersList = list(set(AllUsers))

# %%
def CreateUsers(AllUsersList):

    for user in AllUsersList:
        username = user
        FILENAME = "./users_pkl/"+username+".json"
        
        if not os.path.isfile(FILENAME):        
            query_url = "https://api.github.com/users/%s?access_token=%s" % (username, mystuff.access_token)

            req = urllib.request.Request(query_url)
            try:
                response = urllib.request.urlopen(req)
            except:
                pass
            data = json.loads(response.read())

            user_id = data['id']
            num_followers = data['followers']
            num_following = data['following']
            num_repos = data['public_repos']

            created_at = datetime.datetime.strptime(data['created_at'],'%Y-%m-%dT%H:%M:%SZ')
            created_at = created_at + datetime.timedelta(hours=-5) # EST
            created_at = created_at.strftime('%Y-%m-%d %H:%M:%S')

            with open(FILENAME, 'w') as outfile:
                json.dump(data, outfile)
            print (FILENAME+" saved.")
            time.sleep(1) # stay within API rate limit of 5000 requests / hour + buffer

# %%
CreateUsers(AllUsersList)
# Out:
# ./users_pkl/suyashkumar.json saved.
# ./users_pkl/brendes.json saved.
# ./users_pkl/seerhut.json saved.
# ./users_pkl/ovcharenkoo.json saved.
# ./users_pkl/ZebraTech.json saved.
# ./users_pkl/trbielec.json saved.
# ./users_pkl/znuh.json saved.
# ./users_pkl/antouanbg.json saved.
# ./users_pkl/openube.json saved.
# ./users_pkl/tiborpilz.json saved.
# ./users_pkl/C47D.json saved.
# ./users_pkl/alito.json saved.
# ./users_pkl/panamantis.json saved.
# ./users_pkl/octavianCraciun.json saved.
# ./users_pkl/kylejcarlton.json saved.
# ./users_pkl/tsroka.json saved.
# ./users_pkl/alsrgv.json saved.
# ./users_pkl/ikamthania.json saved.
# ./users_pkl/dzeez.json saved.
# ./users_pkl/dioptre.json saved.
# ./users_pkl/Cosby5.json saved.
# ./users_pkl/jmargeta.json saved.
# ./users_pkl/redaready.json saved.
# ./users_pkl/dev1104.json saved.
# ./users_pkl/amashal.json saved.
# ./users_pkl/trigrass2.json saved.
# ./users_pkl/klonggan.json saved.
# ./users_pkl/Fruiter.json saved.
# ./users_pkl/josemy.json saved.
# ./users_pkl/sysclock.json saved.
# ./users_pkl/JoyDoSun.json saved.
# ./users_pkl/vck.json saved.
# ./users_pkl/jeremiahstover.json saved.
# ./users_pkl/ericyao2013.json saved.
# ./users_pkl/pilanci.json saved.
# ./users_pkl/albertxiao.json saved.
# ./users_pkl/b1tdust.json saved.
# ./users_pkl/codykrieger.json saved.
# ./users_pkl/pkral78.json saved.
# ./users_pkl/riscmcu.json saved.
# ./users_pkl/ckuethe.json saved.
# ./users_pkl/Jaycee0602.json saved.
# ./users_pkl/dmzio.json saved.
# ./users_pkl/AbhishekGhosh.json saved.
# ./users_pkl/kishb87.json saved.
# ./users_pkl/mahiraltay.json saved.
# ./users_pkl/LouisVRX.json saved.
# ./users_pkl/Erhannis.json saved.
# ./users_pkl/DINKIN.json saved.
# ./users_pkl/mlp6.json saved.
# ./users_pkl/oring111.json saved.
# ./users_pkl/Bivi.json saved.
# ./users_pkl/Abyssion.json saved.
# ./users_pkl/danilogr.json saved.
# ./users_pkl/glocklueng.json saved.
# ./users_pkl/mikekim9293.json saved.
# ./users_pkl/andreidavid.json saved.
# ./users_pkl/betolink.json saved.
# ./users_pkl/utommo.json saved.
# ./users_pkl/denisfitz57.json saved.
# ./users_pkl/manis404.json saved.
# ./users_pkl/TroySK.json saved.
# ./users_pkl/h798471649.json saved.
# ./users_pkl/mzojosue.json saved.
# ./users_pkl/simonmd.json saved.
# ./users_pkl/crystalline.json saved.
# ./users_pkl/thiswillbeyourgithub.json saved.
# ./users_pkl/habibzadeh.json saved.
# ./users_pkl/xfce.json saved.
# ./users_pkl/jammie.json saved.
# ./users_pkl/pumpikano.json saved.
# ./users_pkl/lucasfloriani.json saved.
# ./users_pkl/eobodo.json saved.
# ./users_pkl/akashgupta299.json saved.
# ./users_pkl/eastleader1982.json saved.
# ./users_pkl/thewtex.json saved.
# ./users_pkl/capitulation.json saved.
# ./users_pkl/wly0215.json saved.
# ./users_pkl/thecomicopera.json saved.
# ./users_pkl/raffet.json saved.
# ./users_pkl/djson.json saved.
# ./users_pkl/mitoksim.json saved.
# ./users_pkl/chechu2k5.json saved.
# ./users_pkl/DFNOsorio.json saved.
# ./users_pkl/DrKenHo.json saved.
# ./users_pkl/panzerkiller.json saved.
# ./users_pkl/mxochicale.json saved.
# ./users_pkl/IanBoyanZhang.json saved.
# ./users_pkl/huleg.json saved.
# ./users_pkl/ryanmaynard.json saved.
# ./users_pkl/charlestac.json saved.
# ./users_pkl/ARezaK.json saved.
# ./users_pkl/l-n-x.json saved.
# ./users_pkl/XinShuYang.json saved.
# ./users_pkl/tomfleet.json saved.
# ./users_pkl/lucansky.json saved.
# ./users_pkl/lepetitcrack.json saved.
# ./users_pkl/dirm02.json saved.
# ./users_pkl/dzwpusa.json saved.
# ./users_pkl/yanpozka.json saved.
# ./users_pkl/jensstockhausen.json saved.
# ./users_pkl/crmackay.json saved.
# ./users_pkl/ash0080.json saved.
# ./users_pkl/blakme.json saved.
# ./users_pkl/AnttiLukats.json saved.
# ./users_pkl/junhua-zhang.json saved.
# ./users_pkl/jmptable.json saved.
# ./users_pkl/milkowski.json saved.
# ./users_pkl/mohamed.json saved.
# ./users_pkl/yuntianrenren.json saved.
# ./users_pkl/mckaydavis.json saved.
# ./users_pkl/fcqing.json saved.
# ./users_pkl/zhangtemplar.json saved.
# ./users_pkl/eahmedsalman.json saved.
# ./users_pkl/kubawolanin.json saved.
# ./users_pkl/ykeraichia.json saved.
# ./users_pkl/Bobbyjoness.json saved.
# ./users_pkl/HINATASDK.json saved.
# ./users_pkl/DannyRavi.json saved.
# ./users_pkl/thomaschandler.json saved.
# ./users_pkl/maswangy.json saved.
# ./users_pkl/michaeljklein.json saved.
# ./users_pkl/bergeltt.json saved.
# ./users_pkl/nishu0f0.json saved.
# ./users_pkl/robotong.json saved.
# ./users_pkl/Drunkar.json saved.
# ./users_pkl/aa88kk.json saved.
# ./users_pkl/aperocks.json saved.
# ./users_pkl/ltran07.json saved.
# ./users_pkl/tdaitx.json saved.
# ./users_pkl/gilovi.json saved.
# ./users_pkl/codercahol.json saved.
# ./users_pkl/kitspace-forks.json saved.
# ./users_pkl/cuong0993.json saved.
# ./users_pkl/racerxdl.json saved.
# ./users_pkl/iseanstevens.json saved.
# ./users_pkl/thexinchen.json saved.
# ./users_pkl/factsfinder.json saved.
# ./users_pkl/ZTaylor39.json saved.
# ./users_pkl/Tuxified.json saved.
# ./users_pkl/cleder.json saved.
# ./users_pkl/kevinn1999.json saved.
# ./users_pkl/longda.json saved.
# ./users_pkl/utzig.json saved.
# ./users_pkl/espinozg.json saved.
# ./users_pkl/AABatteries.json saved.
# ./users_pkl/clf1985.json saved.
# ./users_pkl/bhattisatish.json saved.
# ./users_pkl/aaronfowles.json saved.
# ./users_pkl/Optoguy.json saved.
# ./users_pkl/SherpaPierpa.json saved.
# ./users_pkl/selftaught.json saved.
# ./users_pkl/goran-mahovlic.json saved.
# ./users_pkl/vokom.json saved.
# ./users_pkl/SpaceBaker.json saved.
# ./users_pkl/10syle.json saved.
# ./users_pkl/edisno.json saved.
# ./users_pkl/fabiogiordani.json saved.
# ./users_pkl/bensooter.json saved.
# ./users_pkl/mustaphee.json saved.
# ./users_pkl/ianblenke.json saved.
# ./users_pkl/g4idrijs.json saved.
# ./users_pkl/msravi.json saved.
# ./users_pkl/JustGitting.json saved.
# ./users_pkl/letoram.json saved.
# ./users_pkl/electronics4fun.json saved.
# ./users_pkl/ThePreviousOne.json saved.
# ./users_pkl/charliegerard.json saved.
# ./users_pkl/0xdevalias.json saved.
# ./users_pkl/GeorgeIoak.json saved.
# ./users_pkl/kovachwt.json saved.
# ./users_pkl/JohnGitHub886.json saved.
# ./users_pkl/amckay1.json saved.
# ./users_pkl/lasc.json saved.
# ./users_pkl/dmitry-sukhoruchkin.json saved.
# ./users_pkl/liuzhiping1.json saved.
# ./users_pkl/ftrentini.json saved.
# ./users_pkl/dezdeepblue.json saved.
# ./users_pkl/lograss.json saved.
# ./users_pkl/MartinBloedorn.json saved.
# ./users_pkl/jayPhantomic.json saved.
# ./users_pkl/dalmago.json saved.
# ./users_pkl/ArsenioDev.json saved.
# ./users_pkl/DuoBelt.json saved.
# ./users_pkl/insidentes.json saved.
# ./users_pkl/mickrideout.json saved.
# ./users_pkl/DengQilong.json saved.
# ./users_pkl/elmsfu.json saved.
# ./users_pkl/Audakel.json saved.
# ./users_pkl/ats777.json saved.
# ./users_pkl/mohammadfatemieh.json saved.
# ./users_pkl/wjx.json saved.
# ./users_pkl/levthedev.json saved.
# ./users_pkl/speters.json saved.
# ./users_pkl/DigiMaxIO.json saved.
# ./users_pkl/kamilchm.json saved.
# ./users_pkl/nksheridan.json saved.
# ./users_pkl/yyyg45.json saved.
# ./users_pkl/smu160.json saved.
# ./users_pkl/tonghuix.json saved.
# ./users_pkl/andrewjaykeller.json saved.
# ./users_pkl/ilovejs.json saved.
# ./users_pkl/Jingfeng-LU.json saved.
# ./users_pkl/wware.json saved.
# ./users_pkl/boyihao-utp.json saved.
# ./users_pkl/hetykai.json saved.
# ./users_pkl/andrewkharook.json saved.
# ./users_pkl/r06548032.json saved.
# ./users_pkl/basharbme.json saved.
# ./users_pkl/tangym.json saved.
# ./users_pkl/kasbah.json saved.
# ./users_pkl/loredanacirstea.json saved.
# ./users_pkl/aperrien.json saved.
# ./users_pkl/diegslva.json saved.
# ./users_pkl/PieterVanBoheemen.json saved.
# ./users_pkl/urill.json saved.
# ./users_pkl/uid89626.json saved.
# ./users_pkl/zrthstr.json saved.
# ./users_pkl/wjawaid.json saved.
# ./users_pkl/Felipeasg.json saved.
# ./users_pkl/Yarulik.json saved.
# ./users_pkl/fucx.json saved.
# ./users_pkl/syberphunk.json saved.
# ./users_pkl/kanzure.json saved.
# ./users_pkl/antoniocarreiro.json saved.
# ./users_pkl/myfreeweb.json saved.
# ./users_pkl/HTMLrat.json saved.
# ./users_pkl/dsalychev.json saved.
# ./users_pkl/ColinChargy.json saved.
# ./users_pkl/masip85.json saved.
# ./users_pkl/mslavescu.json saved.
# ./users_pkl/catterys.json saved.
# ./users_pkl/Bellspringsteen.json saved.
# ./users_pkl/lyorak.json saved.
# ./users_pkl/prasimix.json saved.
# ./users_pkl/nunodotferreira.json saved.
# ./users_pkl/mayere.json saved.
# ./users_pkl/dan2k3k4.json saved.
# ./users_pkl/LiShuai1225.json saved.
# ./users_pkl/jdesbonnet.json saved.
# ./users_pkl/serhargun.json saved.
# ./users_pkl/davidonet.json saved.
# ./users_pkl/Antownee.json saved.
# ./users_pkl/metanoic.json saved.
# ./users_pkl/AmitShah.json saved.
# ./users_pkl/Alberts00.json saved.
# ./users_pkl/gt50.json saved.
# ./users_pkl/kenkeiter.json saved.
# ./users_pkl/rene-aguirre.json saved.
# ./users_pkl/CWCorrea.json saved.
# ./users_pkl/hwwong.json saved.
# ./users_pkl/rexpan.json saved.
# ./users_pkl/AmarPrabhu.json saved.
# ./users_pkl/kilianbreathnach.json saved.
# ./users_pkl/747500.json saved.
# ./users_pkl/nikharris0.json saved.
# ./users_pkl/zentown.json saved.
# ./users_pkl/07bm27.json saved.
# ./users_pkl/fabriciopk.json saved.
# ./users_pkl/sponnusa.json saved.
# ./users_pkl/GitMoDu.json saved.
# ./users_pkl/mkubdev.json saved.
# ./users_pkl/BillBrower.json saved.
# ./users_pkl/anfractuosity.json saved.
# ./users_pkl/bobnet.json saved.
# ./users_pkl/annafieber.json saved.
# ./users_pkl/dylanized.json saved.
# ./users_pkl/jonnydubowsky.json saved.
# ./users_pkl/mikebebjak.json saved.
# ./users_pkl/TobiG77.json saved.
# ./users_pkl/huangguojun.json saved.
# ./users_pkl/jtwiefel.json saved.
# ./users_pkl/yangjion.json saved.
# ./users_pkl/luojxxx.json saved.
# ./users_pkl/nyok.json saved.
# ./users_pkl/tinlokchan.json saved.
# ./users_pkl/davidmoshal.json saved.
# ./users_pkl/qinshiysb.json saved.
# ./users_pkl/ahmgeek.json saved.
# ./users_pkl/reportingsjr.json saved.
# ./users_pkl/theg4sh.json saved.
# ./users_pkl/kskyten.json saved.
# ./users_pkl/mediovia.json saved.
# ./users_pkl/kaosat-dev.json saved.
# ./users_pkl/TLmaK0.json saved.
# ./users_pkl/joer14.json saved.
# ./users_pkl/fsequeira1.json saved.
# ./users_pkl/kickhad.json saved.
# ./users_pkl/livitki.json saved.
# ./users_pkl/procommerz.json saved.
# ./users_pkl/docfabio.json saved.
# ./users_pkl/JeanRintoul.json saved.
# ./users_pkl/matlab379.json saved.
# ./users_pkl/Surfndez.json saved.
# ./users_pkl/masoud-al.json saved.
# ./users_pkl/416104443.json saved.
# ./users_pkl/qirex.json saved.
# ./users_pkl/GDI123.json saved.
# ./users_pkl/tonyzzr.json saved.
# ./users_pkl/ajtoo.json saved.
# ./users_pkl/ajkatom.json saved.
# ./users_pkl/PanPan0210.json saved.
# ./users_pkl/riki8686.json saved.
# ./users_pkl/di1eep.json saved.
# ./users_pkl/r4forth.json saved.
# ./users_pkl/jaanpehechaanho.json saved.
# ./users_pkl/lancemk.json saved.
# ./users_pkl/noetzelj.json saved.
# ./users_pkl/merqurio.json saved.
# ./users_pkl/aCrazyCoder.json saved.
# ./users_pkl/zer0def.json saved.
# ./users_pkl/PavelkoDmitriy.json saved.
# ./users_pkl/Palantir555.json saved.
# ./users_pkl/Guokr1991.json saved.
# ./users_pkl/alexsorokoletov.json saved.
# ./users_pkl/withitren.json saved.
# ./users_pkl/yosyp.json saved.
# ./users_pkl/cmadh.json saved.
# ./users_pkl/JamesHagerman.json saved.
# ./users_pkl/soobash.json saved.
# ./users_pkl/cvabc.json saved.
# ./users_pkl/orakle.json saved.
# ./users_pkl/RedToast.json saved.
# ./users_pkl/nrepian.json saved.
# ./users_pkl/ersinpw.json saved.
# ./users_pkl/Nguy3nM1nhVu0ng.json saved.
# ./users_pkl/a67878813.json saved.
# ./users_pkl/vitlib.json saved.
# ./users_pkl/robksawyer.json saved.
# ./users_pkl/imgntn.json saved.
# ./users_pkl/gitbochs.json saved.
# ./users_pkl/knightlore.json saved.
# ./users_pkl/baibaratsky.json saved.
# ./users_pkl/cooldenng.json saved.
# ./users_pkl/cnc4less.json saved.
# ./users_pkl/bitacademy-howl.json saved.
# ./users_pkl/Graal76.json saved.
# ./users_pkl/jeongkyu.json saved.
# ./users_pkl/vehar.json saved.
# ./users_pkl/julescarbon.json saved.
# ./users_pkl/zhouzhuhuang.json saved.
# ./users_pkl/langthom.json saved.
# ./users_pkl/wildlyinaccurate.json saved.
# ./users_pkl/Doom4535.json saved.
# ./users_pkl/josecohenca.json saved.
# ./users_pkl/pdp7.json saved.
# ./users_pkl/djsbriscoe.json saved.
# ./users_pkl/imgray.json saved.
# ./users_pkl/QuantumZhang.json saved.
# ./users_pkl/pompel123.json saved.
# ./users_pkl/deebot.json saved.
# ./users_pkl/wlmeng11.json saved.
# ./users_pkl/airsus.json saved.
# ./users_pkl/andrerovani.json saved.
# ./users_pkl/longcongduoi.json saved.
# ./users_pkl/dreamkeep.json saved.
# ./users_pkl/irosyadi.json saved.
# ./users_pkl/olihb.json saved.
# ./users_pkl/hipotenuso13.json saved.
# ./users_pkl/Hendryputra.json saved.
# ./users_pkl/trungnpt.json saved.
# ./users_pkl/sunjiangbo.json saved.
# ./users_pkl/ebgaaron.json saved.
# ./users_pkl/DragonStuff.json saved.
# ./users_pkl/artursg.json saved.
# ./users_pkl/grahamjenson.json saved.
# ./users_pkl/E3V3A.json saved.
# ./users_pkl/rcaisse2722.json saved.
# ./users_pkl/zhangsinap.json saved.
# ./users_pkl/bottlerocket.json saved.
# ./users_pkl/gaurav000144.json saved.
# ./users_pkl/YaweiZhao.json saved.
# ./users_pkl/goeblr.json saved.
# ./users_pkl/rapha-opensource.json saved.
# ./users_pkl/taopanpan.json saved.
# ./users_pkl/Mephistofeles.json saved.
# ./users_pkl/franchb.json saved.
# ./users_pkl/medul6.json saved.
# ./users_pkl/smcgill3.json saved.
# ./users_pkl/ChunHsinTung.json saved.
# ./users_pkl/heymarcin.json saved.
# ./users_pkl/blueintegral.json saved.
# ./users_pkl/jekader.json saved.
# ./users_pkl/kelu124.json saved.
# ./users_pkl/harlanw.json saved.
# ./users_pkl/rrozestw.json saved.
# ./users_pkl/justicelee.json saved.
# ./users_pkl/Jae-hyun.json saved.
# ./users_pkl/Jay1Kumr.json saved.
# ./users_pkl/albermav.json saved.
# ./users_pkl/twobit.json saved.
# ./users_pkl/gelonsun.json saved.
# ./users_pkl/sdd.json saved.
# ./users_pkl/suoto.json saved.
# ./users_pkl/GCY.json saved.
# ./users_pkl/makinteract.json saved.
# ./users_pkl/KonradStanski.json saved.
# ./users_pkl/PureEngineering.json saved.
# ./users_pkl/bafeigum.json saved.
# ./users_pkl/bipbipcorp.json saved.
# ./users_pkl/nukem.json saved.
# ./users_pkl/ajugeorge93.json saved.
# ./users_pkl/leonidkozhukh.json saved.
# ./users_pkl/paul-monokoto.json saved.
# ./users_pkl/DjalelBBZ.json saved.
# ./users_pkl/cHemingway.json saved.
# ./users_pkl/hpennington.json saved.
# ./users_pkl/agdenadel.json saved.
# ./users_pkl/Samsonsjarkal.json saved.
# ./users_pkl/akc5233206.json saved.
# ./users_pkl/mtubpeng1.json saved.
# ./users_pkl/AdLibitumTechnologies.json saved.
# ./users_pkl/jarmitage.json saved.
# ./users_pkl/pablomelo.json saved.
# ./users_pkl/Ritaqk.json saved.
# ./users_pkl/bigbag.json saved.
# ./users_pkl/guillaumedavidphd.json saved.
# ./users_pkl/MeFri.json saved.
# ./users_pkl/robmarkcole.json saved.
# ./users_pkl/awantae.json saved.
# ./users_pkl/shakhmetov.json saved.
# ./users_pkl/ascillato.json saved.
# ./users_pkl/DircoDT.json saved.

# %%
def getStarsUSER(USERNAME):


    page_number = 0
    users_processed = 0
    stars_remaining = True
    list_stars = []
 

    ###
    ###    This block of code creates a list of tuples in the form of (username, star_time)
    ###    for the Statgazers, which will laterbe used to extract full GitHub profile data
    ###
    FILENAME = "./users_pkl/"+USERNAME+"_stars.json"
    if not os.path.isfile(FILENAME):
        
        while stars_remaining:
            
            time.sleep(1)
            query_url = "https://api.github.com/users/%s/starred?page=%s&access_token=%s" % (USERNAME, page_number, mystuff.access_token)

            req = urllib.request.Request(query_url)
            req.add_header('Accept', 'application/vnd.github.v3.star+json')
            try:
                response = urllib.request.urlopen(req)
            except:
                pass
            data = json.loads(response.read())
            for k in data:
                list_stars.append(k)
                
            if len(data) < 25:
                stars_remaining = False

            page_number += 1
             
        with open(FILENAME, 'w') as outfile:
            json.dump(list_stars, outfile)
        print (FILENAME+" saved.")
        return list_stars
    else:
        (FILENAME+" existed.")
    return 'Exists'

# %%
for k in AllUsersList:
    getStarsUSER(k)
# Out:
# ./users_pkl/suyashkumar_stars.json saved.
# ./users_pkl/brendes_stars.json saved.
# ./users_pkl/seerhut_stars.json saved.
# ./users_pkl/ovcharenkoo_stars.json saved.
# ./users_pkl/ZebraTech_stars.json saved.
# ./users_pkl/trbielec_stars.json saved.
# ./users_pkl/znuh_stars.json saved.
# ./users_pkl/antouanbg_stars.json saved.
# ./users_pkl/openube_stars.json saved.
# ./users_pkl/tiborpilz_stars.json saved.
# ./users_pkl/C47D_stars.json saved.
# ./users_pkl/alito_stars.json saved.
# ./users_pkl/panamantis_stars.json saved.
# ./users_pkl/octavianCraciun_stars.json saved.
# ./users_pkl/kylejcarlton_stars.json saved.
# ./users_pkl/tsroka_stars.json saved.
# ./users_pkl/alsrgv_stars.json saved.
# ./users_pkl/ikamthania_stars.json saved.
# ./users_pkl/dzeez_stars.json saved.
# ./users_pkl/dioptre_stars.json saved.
# ./users_pkl/Cosby5_stars.json saved.
# ./users_pkl/jmargeta_stars.json saved.
# ./users_pkl/redaready_stars.json saved.
# ./users_pkl/dev1104_stars.json saved.
# ./users_pkl/amashal_stars.json saved.
# ./users_pkl/trigrass2_stars.json saved.
# ./users_pkl/klonggan_stars.json saved.
# ./users_pkl/Fruiter_stars.json saved.
# ./users_pkl/josemy_stars.json saved.
# ./users_pkl/sysclock_stars.json saved.
# ./users_pkl/JoyDoSun_stars.json saved.
# ./users_pkl/vck_stars.json saved.
# ./users_pkl/jeremiahstover_stars.json saved.
# ./users_pkl/ericyao2013_stars.json saved.
# ./users_pkl/pilanci_stars.json saved.
# ./users_pkl/albertxiao_stars.json saved.
# ./users_pkl/b1tdust_stars.json saved.
# ./users_pkl/codykrieger_stars.json saved.
# ./users_pkl/pkral78_stars.json saved.
# ./users_pkl/riscmcu_stars.json saved.
# ./users_pkl/ckuethe_stars.json saved.
# ./users_pkl/Jaycee0602_stars.json saved.
# ./users_pkl/dmzio_stars.json saved.
# ./users_pkl/AbhishekGhosh_stars.json saved.
# ./users_pkl/kishb87_stars.json saved.
# ./users_pkl/mahiraltay_stars.json saved.
# ./users_pkl/LouisVRX_stars.json saved.
# ./users_pkl/Erhannis_stars.json saved.
# ./users_pkl/DINKIN_stars.json saved.
# ./users_pkl/mlp6_stars.json saved.
# ./users_pkl/oring111_stars.json saved.
# ./users_pkl/Bivi_stars.json saved.
# ./users_pkl/Abyssion_stars.json saved.
# ./users_pkl/danilogr_stars.json saved.
# ./users_pkl/glocklueng_stars.json saved.
# ./users_pkl/mikekim9293_stars.json saved.
# ./users_pkl/andreidavid_stars.json saved.
# ./users_pkl/betolink_stars.json saved.
# ./users_pkl/utommo_stars.json saved.
# ./users_pkl/denisfitz57_stars.json saved.
# ./users_pkl/manis404_stars.json saved.
# ./users_pkl/TroySK_stars.json saved.
# ./users_pkl/h798471649_stars.json saved.
# ./users_pkl/mzojosue_stars.json saved.
# ./users_pkl/simonmd_stars.json saved.
# ./users_pkl/crystalline_stars.json saved.
# ./users_pkl/thiswillbeyourgithub_stars.json saved.
# ./users_pkl/habibzadeh_stars.json saved.
# ./users_pkl/xfce_stars.json saved.
# ./users_pkl/jammie_stars.json saved.
# ./users_pkl/pumpikano_stars.json saved.
# ./users_pkl/lucasfloriani_stars.json saved.
# ./users_pkl/eobodo_stars.json saved.
# ./users_pkl/akashgupta299_stars.json saved.
# ./users_pkl/eastleader1982_stars.json saved.
# ./users_pkl/thewtex_stars.json saved.
# ./users_pkl/capitulation_stars.json saved.
# ./users_pkl/wly0215_stars.json saved.
# ./users_pkl/thecomicopera_stars.json saved.
# ./users_pkl/raffet_stars.json saved.
# ./users_pkl/djson_stars.json saved.
# ./users_pkl/mitoksim_stars.json saved.
# ./users_pkl/chechu2k5_stars.json saved.
# ./users_pkl/DFNOsorio_stars.json saved.
# ./users_pkl/DrKenHo_stars.json saved.
# ./users_pkl/panzerkiller_stars.json saved.
# ./users_pkl/mxochicale_stars.json saved.
# ./users_pkl/IanBoyanZhang_stars.json saved.
# ./users_pkl/huleg_stars.json saved.
# ./users_pkl/ryanmaynard_stars.json saved.
# ./users_pkl/charlestac_stars.json saved.
# ./users_pkl/ARezaK_stars.json saved.
# ./users_pkl/l-n-x_stars.json saved.
# ./users_pkl/XinShuYang_stars.json saved.
# ./users_pkl/tomfleet_stars.json saved.
# ./users_pkl/lucansky_stars.json saved.
# ./users_pkl/lepetitcrack_stars.json saved.
# ./users_pkl/dirm02_stars.json saved.
# ./users_pkl/dzwpusa_stars.json saved.
# ./users_pkl/yanpozka_stars.json saved.
# ./users_pkl/jensstockhausen_stars.json saved.
# ./users_pkl/crmackay_stars.json saved.
# ./users_pkl/ash0080_stars.json saved.
# ./users_pkl/blakme_stars.json saved.
# ./users_pkl/AnttiLukats_stars.json saved.
# ./users_pkl/junhua-zhang_stars.json saved.
# ./users_pkl/jmptable_stars.json saved.
# ./users_pkl/milkowski_stars.json saved.
# ./users_pkl/mohamed_stars.json saved.
# ./users_pkl/yuntianrenren_stars.json saved.
# ./users_pkl/mckaydavis_stars.json saved.
# ./users_pkl/fcqing_stars.json saved.
# ./users_pkl/zhangtemplar_stars.json saved.
# ./users_pkl/eahmedsalman_stars.json saved.
# ./users_pkl/kubawolanin_stars.json saved.
# ./users_pkl/ykeraichia_stars.json saved.
# ./users_pkl/Bobbyjoness_stars.json saved.
# ./users_pkl/HINATASDK_stars.json saved.
# ./users_pkl/DannyRavi_stars.json saved.
# ./users_pkl/thomaschandler_stars.json saved.
# ./users_pkl/maswangy_stars.json saved.
# ./users_pkl/michaeljklein_stars.json saved.
# ./users_pkl/bergeltt_stars.json saved.
# ./users_pkl/nishu0f0_stars.json saved.
# ./users_pkl/robotong_stars.json saved.
# ./users_pkl/Drunkar_stars.json saved.
# ./users_pkl/aa88kk_stars.json saved.
# ./users_pkl/aperocks_stars.json saved.
# ./users_pkl/ltran07_stars.json saved.
# ./users_pkl/tdaitx_stars.json saved.
# ./users_pkl/gilovi_stars.json saved.
# ./users_pkl/codercahol_stars.json saved.
# ./users_pkl/kitspace-forks_stars.json saved.
# ./users_pkl/cuong0993_stars.json saved.
# ./users_pkl/racerxdl_stars.json saved.
# ./users_pkl/iseanstevens_stars.json saved.
# ./users_pkl/thexinchen_stars.json saved.
# ./users_pkl/factsfinder_stars.json saved.
# ./users_pkl/ZTaylor39_stars.json saved.
# ./users_pkl/Tuxified_stars.json saved.
# ./users_pkl/cleder_stars.json saved.
# ./users_pkl/kevinn1999_stars.json saved.
# ./users_pkl/longda_stars.json saved.
# ./users_pkl/utzig_stars.json saved.
# ./users_pkl/espinozg_stars.json saved.
# ./users_pkl/AABatteries_stars.json saved.
# ./users_pkl/clf1985_stars.json saved.
# ./users_pkl/bhattisatish_stars.json saved.
# ./users_pkl/aaronfowles_stars.json saved.
# ./users_pkl/Optoguy_stars.json saved.
# ./users_pkl/SherpaPierpa_stars.json saved.
# ./users_pkl/selftaught_stars.json saved.
# ./users_pkl/goran-mahovlic_stars.json saved.
# ./users_pkl/vokom_stars.json saved.
# ./users_pkl/SpaceBaker_stars.json saved.
# ./users_pkl/10syle_stars.json saved.
# ./users_pkl/edisno_stars.json saved.
# ./users_pkl/fabiogiordani_stars.json saved.
# ./users_pkl/bensooter_stars.json saved.
# ./users_pkl/mustaphee_stars.json saved.
# ./users_pkl/ianblenke_stars.json saved.
# ./users_pkl/g4idrijs_stars.json saved.
# ./users_pkl/msravi_stars.json saved.
# ./users_pkl/JustGitting_stars.json saved.
# ./users_pkl/letoram_stars.json saved.
# ./users_pkl/electronics4fun_stars.json saved.
# ./users_pkl/ThePreviousOne_stars.json saved.
# ./users_pkl/charliegerard_stars.json saved.
# ./users_pkl/0xdevalias_stars.json saved.
# ./users_pkl/GeorgeIoak_stars.json saved.
# ./users_pkl/kovachwt_stars.json saved.
# ./users_pkl/JohnGitHub886_stars.json saved.
# ./users_pkl/amckay1_stars.json saved.
# ./users_pkl/lasc_stars.json saved.
# ./users_pkl/dmitry-sukhoruchkin_stars.json saved.
# ./users_pkl/liuzhiping1_stars.json saved.
# ./users_pkl/ftrentini_stars.json saved.
# ./users_pkl/dezdeepblue_stars.json saved.
# ./users_pkl/lograss_stars.json saved.
# ./users_pkl/MartinBloedorn_stars.json saved.
# ./users_pkl/jayPhantomic_stars.json saved.
# ./users_pkl/dalmago_stars.json saved.
# ./users_pkl/ArsenioDev_stars.json saved.
# ./users_pkl/DuoBelt_stars.json saved.
# ./users_pkl/insidentes_stars.json saved.
# ./users_pkl/mickrideout_stars.json saved.
# ./users_pkl/DengQilong_stars.json saved.
# ./users_pkl/elmsfu_stars.json saved.
# ./users_pkl/Audakel_stars.json saved.
# ./users_pkl/ats777_stars.json saved.
# ./users_pkl/mohammadfatemieh_stars.json saved.
# ./users_pkl/wjx_stars.json saved.
# ./users_pkl/levthedev_stars.json saved.
# ./users_pkl/speters_stars.json saved.
# ./users_pkl/DigiMaxIO_stars.json saved.
# ./users_pkl/kamilchm_stars.json saved.
# ./users_pkl/nksheridan_stars.json saved.
# ./users_pkl/yyyg45_stars.json saved.
# ./users_pkl/smu160_stars.json saved.
# ./users_pkl/tonghuix_stars.json saved.
# ./users_pkl/andrewjaykeller_stars.json saved.
# ./users_pkl/ilovejs_stars.json saved.
# ./users_pkl/Jingfeng-LU_stars.json saved.
# ./users_pkl/wware_stars.json saved.
# ./users_pkl/boyihao-utp_stars.json saved.
# ./users_pkl/hetykai_stars.json saved.
# ./users_pkl/andrewkharook_stars.json saved.
# ./users_pkl/r06548032_stars.json saved.
# ./users_pkl/basharbme_stars.json saved.
# ./users_pkl/tangym_stars.json saved.
# ./users_pkl/kasbah_stars.json saved.

# %%
getStars("kelu124","murgen-dev-kit")
getForks("kelu124","murgen-dev-kit")
getInfo("kelu124","murgen-dev-kit")
getWatcher("kelu124","murgen-dev-kit")

# %%
getStars("kelu124","bomanz")
getForks("kelu124","bomanz")
getInfo("kelu124","bomanz")
getWatcher("kelu124","bomanz")
# Out:
# Gathering Stargazers for kelu124/bomanz...
# Done Gathering Stargazers for kelu124/bomanz!
# Done Gathering subscribers for kelu124/bomanz!
# Gathering subscribers for kelu124/bomanz...
# Done Gathering subscribers for kelu124/bomanz!
# Gathering Stargazers for kelu124/bomanz...
# Done Gathering Stargazers for kelu124/bomanz!
# Now Gathering Stargazers' GitHub Profiles...
# ['user_id', 'username', 'num_followers', 'num_following', 'num_repos', 'created_at', 'star_time']
# Gathering subscribers for kelu124/bomanz...
# Done Gathering subscribers for kelu124/bomanz!
# ['kelu124', 'xfce', 'LouisVRX', 'kasbah']

# %%
getStars("kelu124","pyUProbe1")
getForks("kelu124","pyUProbe1")
getInfo("kelu124","pyUProbe1")
getWatcher("kelu124","pyUProbe1")
# Out:
# Gathering Stargazers for kelu124/pyUProbe1...
# Done Gathering Stargazers for kelu124/pyUProbe1!
# Done Gathering subscribers for kelu124/pyUProbe1!
# Gathering subscribers for kelu124/pyUProbe1...
# Done Gathering subscribers for kelu124/pyUProbe1!
# Gathering Stargazers for kelu124/pyUProbe1...
# Done Gathering Stargazers for kelu124/pyUProbe1!
# Now Gathering Stargazers' GitHub Profiles...
# ['user_id', 'username', 'num_followers', 'num_following', 'num_repos', 'created_at', 'star_time']
# Gathering subscribers for kelu124/pyUProbe1...
# Done Gathering subscribers for kelu124/pyUProbe1!
# ['kelu124', 'klonggan', 'mxochicale']
